# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# In den Ordner wechseln
# %cd /content/drive/MyDrive/techlabs_trees_26
# Out:
# /content/drive/MyDrive/techlabs_trees_26

# %%
# Identität für den Commit hinterlegen
# !git config --global user.email "moritz.rueller@uni-muenster.de"
# !git config --global user.name "MoritzoTheCoder"

# %%
# !echo -e "\nDATA/" >> .gitignore

# %%
import os
from google.colab import userdata

try:
    token = userdata.get('GH_TOKEN')
    # HIER IST DIE KORRIGIERTE ZEILE:
    # !git remote set-url origin https://MoritzoTheCoder:$token@github.com/SarahRinke/techlabs_trees_26.git
    print("✓ Autorisierung erfolgreich vorbereitet.")
except Exception as e:
    print("❌ Fehler beim Laden des Tokens:", e)
# Out:
# ✓ Autorisierung erfolgreich vorbereitet.

# %%
# 1. Änderungen von GitHub im Hintergrund abholen
# !git fetch origin main

# 2. Automatisch zusammenführen ohne Interaktions-Aufforderung
# !git merge origin/main --no-edit
# Out:
# From https://github.com/SarahRinke/techlabs_trees_26
#  * branch            main       -> FETCH_HEAD
# fatal: You have not concluded your merge (MERGE_HEAD exists).
# Please, commit your changes before you merge.

# %%
# 1. Sicherstellen, dass wir im Ordner sind
# %cd /content/drive/MyDrive/techlabs_tress_2026

# 2. Die große Modell-Datei aus dem Git-Index löschen (sie bleibt auf Ihrem Drive erhalten!)
# !git rm --cached fasterrcnn_trees.pth

# 3. Die Modell-Datei und alle zukünftigen .pth-Dateien in die .gitignore eintragen
# !echo -e "\nfasterrcnn_trees.pth" >> .gitignore
# !echo -e "*.pth" >> .gitignore

# 4. Den DATA-Ordner wieder temporär verstecken, falls er nach dem letzten Abbruch noch da ist
import os
if os.path.exists("DATA"):
    os.rename("DATA", "DATA_HIDDEN_FOR_GIT")

# 5. Den Commit mit der bereinigten Dateiliste neu erstellen
# !git add .
# !git commit -m "Modell-Datei entfernt und Programmierarbeit vorbereitet"

# 6. Den Push ohne die große Datei abschicken
# !git push origin HEAD:main --force

# 7. Den DATA-Ordner wieder für Ihr Notebook sichtbar machen
if os.path.exists("DATA_HIDDEN_FOR_GIT"):
    os.rename("DATA_HIDDEN_FOR_GIT", "DATA")
    print("✓ DATA-Ordner wieder hergestellt.")
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/techlabs_tress_2026'
# /content/drive/MyDrive/techlabs_trees_26
# rm 'fasterrcnn_trees.pth'
# [christian_coded 01f84c5] Modell-Datei entfernt und Programmierarbeit vorbereitet
#  14 files changed, 43125 insertions(+), 1 deletion(-)
#  create mode 100644 DATA_HIDDEN_FOR_GIT/baeume.gpkg
#  create mode 100644 DATA_HIDDEN_FOR_GIT/dop10rgbi_32_404_5757_1_nw_2020.jp2
#  create mode 100644 DATA_HIDDEN_FOR_GIT/dop10rgbi_32_404_5758_1_nw_2020.jp2
#  create mode 100644 DATA_HIDDEN_FOR_GIT/dop10rgbi_32_405_5757_1_nw_2020.jp2
#  create mode 100644 DATA_HIDDEN_FOR_GIT/dop10rgbi_32_405_5758_1_nw_2020.jp2
#  create mode 100644 DATA_HIDDEN_FOR_GIT/gruen_opendata.geojson
#  create mode 100644 DATA_HIDDEN_FOR_GIT/more_tiles/dop10rgbi_32_404_5759_1_nw_2020.jp2
#  create mode 100644 DATA_HIDDEN_FOR_GIT/more_tiles/dop10rgbi_32_405_5759_1_nw_2020.jp2
#  create mode 100644 DATA_HIDDEN_FOR_GIT/more_tiles/dop10rgbi_32_406_5757_1_nw_2020.jp2
# ...

# %%
# 1. Sicherstellen, dass wir im korrekten Ordner sind
# %cd /content/drive/MyDrive/techlabs_trees_26

# 2. Den DATA-Ordner verstecken (falls noch nicht geschehen)
import os
if os.path.exists("DATA"):
    os.rename("DATA", "DATA_HIDDEN_FOR_GIT")

# 3. Den alten, schweren Git-Verlauf lokal bereinigen (Soft-Reset)
# Das löscht KEINE Ihrer Dateien, sondern nur das verstopfte Git-Upload-Paket
# !git reset origin/main

# 4. Alles neu verpacken (jetzt garantiert OHNE die .pth-Datei und OHNE DATA)
# !echo -e "\nfasterrcnn_trees.pth\n*.pth\nDATA/" >> .gitignore
# !git add .
# !git commit -m "Sauberer Code-Upload ohne Grossdateien"

# 5. Den Push ausführen (Das wird jetzt blitzschnell gehen, da das Paket winzig ist)
# !git push origin HEAD:main --force

# 6. DATA-Ordner wieder zurückholen
if os.path.exists("DATA_HIDDEN_FOR_GIT"):
    os.rename("DATA_HIDDEN_FOR_GIT", "DATA")
    print("✓ DATA-Ordner wieder da. Fertig!")
